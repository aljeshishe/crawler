# %%
import boto3
import pandas as pd
from dynamo_pandas import put_df, get_df, keys

# %%
def upload_to_dynamodb(df, table_name):
    dynamodb = boto3.resource('dynamodb')
    table = dynamodb.Table(table_name)
    with table.batch_writer() as batch:
        for index, row in df.iterrows():
            batch.put_item(Item=row.to_dict())

# %%
df = pd.read_pickle("/Users/alexeygrachev/Desktop/git/airbnbcrawl/artifacts/221124-210206/data.zip")
df
# Out:
#                       listing_avgRatingA11yLabel listing_avgRatingLocalized  \
# 0                              New place to stay                        New
# 1                              New place to stay                        New
# 2                              New place to stay                        New
# 3      4.56 out of 5 average rating,  32 reviews                  4.56 (32)
# 4      4.63 out of 5 average rating,  31 reviews                  4.63 (31)
# ...                                          ...                        ...
# 40536                                       None                       None
# 40537                                       None                       None
# 40538                                       None                       None
# 40539                                       None                       None
# 40540                                       None                       None
#
#          listing_city  listing_contextualPicturesCount  \
# 0                 Kaş                              6.0
# 1                 Kaş                             11.0
# 2                 Kaş                             19.0
# 3      Gökçeören Köyü                             13.0
# 4                 Kaş                             14.0
# ...               ...                              ...
# 40536            None                              7.0
# 40537        T'bilisi                             15.0
# 40538        T'bilisi                             11.0
# 40539        T'bilisi                             17.0
# 40540        T'bilisi                             29.0
#
#       listing_contextualPicturesPageInfo_endCursor  \
# 0                                             None
# 1                                             NQ==
# 2                                             NQ==
# 3                                             NQ==
# 4                                             NQ==
# ...                                            ...
# 40536                                         NQ==
# 40537                                         NQ==
# 40538                                         NQ==
# 40539                                         NQ==
# 40540                                         NQ==
#
#       listing_contextualPicturesPageInfo_hasNextPage  \
# 0                                              False
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
# ...                                              ...
# 40536                                           True
# 40537                                           True
# 40538                                           True
# 40539                                           True
# 40540                                           True
#
#       listing_contextualPicturesPageInfo_hasPreviousPage  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 40536                                              False
# 40537                                              False
# 40538                                              False
# 40539                                              False
# 40540                                              False
#
#        listing_contextualPicturesPageInfo_startCursor  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 40536                                             NaN
# 40537                                             NaN
# 40538                                             NaN
# 40539                                             NaN
# 40540                                             NaN
#
#        listing_coordinate_latitude  listing_coordinate_longitude  ...  \
# 0                        36.203008                     29.639369  ...
# 1                        36.264302                     29.493958  ...
# 2                        36.269610                     29.415060  ...
# 3                        36.221524                     29.554669  ...
# 4                        36.216250                     29.685360  ...
# ...                            ...                           ...  ...
# 40536                    41.788980                     45.002530  ...
# 40537                    41.688910                     44.798360  ...
# 40538                    41.807280                     44.780240  ...
# 40539                    41.681280                     44.835990  ...
# 40540                    41.688220                     44.840060  ...
#
#       structuredStayDisplayPrice_primaryLine_concatQualifierLeft  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40536                                                NaN
# 40537                                                NaN
# 40538                                                NaN
# 40539                                                NaN
# 40540                                                NaN
#
#       structuredStayDisplayPrice_primaryLine_trailingContent  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40536                                                NaN
# 40537                                                NaN
# 40538                                                NaN
# 40539                                                NaN
# 40540                                                NaN
#
#       structuredStayDisplayPrice_secondaryLine_displayComponentType  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40536                                                NaN
# 40537                                                NaN
# 40538                                                NaN
# 40539                                                NaN
# 40540                                                NaN
#
#       structuredStayDisplayPrice_secondaryLine_accessibilityLabel  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40536                                                NaN
# 40537                                                NaN
# 40538                                                NaN
# 40539                                                NaN
# 40540                                                NaN
#
#       structuredStayDisplayPrice_secondaryLine_price  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 40536                                            NaN
# 40537                                            NaN
# 40538                                            NaN
# 40539                                            NaN
# 40540                                            NaN
#
#        structuredStayDisplayPrice_secondaryLine_trailingContent  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40536                                                NaN
# 40537                                                NaN
# 40538                                                NaN
# 40539                                                NaN
# 40540                                                NaN
#
#        structuredStayDisplayPrice_explanationData_title  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 40536                                               NaN
# 40537                                               NaN
# 40538                                               NaN
# 40539                                               NaN
# 40540                                               NaN
#
#        structuredStayDisplayPrice_explanationDataDisplayPosition  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40536                                                NaN
# 40537                                                NaN
# 40538                                                NaN
# 40539                                                NaN
# 40540                                                NaN
#
#        structuredStayDisplayPrice_explanationDataDisplayPriceTriggerType  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 40536                                                NaN
# 40537                                                NaN
# 40538                                                NaN
# 40539                                                NaN
# 40540                                                NaN
#
#        structuredStayDisplayPrice_layout
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 40536                                NaN
# 40537                                NaN
# 40538                                NaN
# 40539                                NaN
# 40540                                NaN
#
# [40541 rows x 74 columns]

# %%
df = df[~df.duplicated("listing_id")]

# %%
df["listing_id"] = df["listing_id"].astype(str)
put_df(df, table="tmp_airbnb")
# Out:
# /var/folders/tp/b6czj_6x4q3f4qhdb47cj5d00000gp/T/ipykernel_1849/1961306567.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["listing_id"] = df["listing_id"].astype(str)
# ---------------------------------------------------------------------------
# ProvisionedThroughputExceededException    Traceback (most recent call last)
# Cell In [54], line 2
#       1 df["listing_id"] = df["listing_id"].astype(str)
# ----> 2 put_df(df, table="tmp_airbnb")
#
# File ~/Desktop/git/crawler/aws-python-scheduled-cron-project/.venv/lib/python3.10/site-packages/dynamo_pandas/dynamo_pandas.py:215, in put_df(df, table, boto3_kwargs)
#     181 def put_df(df, *, table, boto3_kwargs={}):
#     182     """Put rows of a dataframe as items into a table. If the item(s) do not exist in the
#     183     table they are created, otherwise the existing items are replaced with the new ones.
#     184
#    (...)
#     213     >>> put_df(players_df, table="players")
#     214     """  # noqa: E501
# --> 215     put_items(items=_to_items(df), table=table, boto3_kwargs=boto3_kwargs)
#
# File ~/Desktop/git/crawler/aws-python-scheduled-cron-project/.venv/lib/python3.10/site-packages/dynamo_pandas/transactions/transactions.py:339, in put_items(items, table, boto3_kwargs)
#     336 batch_items = items_to_process[:batch_size]
#     337 items_to_process = items_to_process[batch_size:]
# --> 339 unprocessed_items = _put_items(batch_items, table, boto3_kwargs)
#     341 if len(unprocessed_items) > batch_size // 2:
#     342     batch_size = max(batch_size // 2, 1)
#
# File ~/Desktop/git/crawler/aws-python-scheduled-cron-project/.venv/lib/python3.10/site-packages/dynamo_pandas/transactions/transactions.py:282, in _put_items(items, table, boto3_kwargs)
#     278 """Adapter function to format the items, call the client batch_write_item function
#     279 and return the unprocessed items (if any) in the format they were provided."""
#     280 client = boto3.client("dynamodb", **boto3_kwargs)
# --> 282 response = client.batch_write_item(
#     283     RequestItems={table: [{"PutRequest": {"Item": item}} for item in items]}
#     284 )
#     286 if response["UnprocessedItems"] != {}:
#     287     return [
#     288         item["PutRequest"]["Item"] for item in response["UnprocessedItems"][table]
#     289     ]
#
# File ~/Desktop/git/crawler/aws-python-scheduled-cron-project/.venv/lib/python3.10/site-packages/botocore/client.py:530, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     526     raise TypeError(
#     527         f"{py_operation_name}() only accepts keyword arguments."
#     528     )
#     529 # The "self" in this scope is referring to the BaseClient.
# --> 530 return self._make_api_call(operation_name, kwargs)
#
# File ~/Desktop/git/crawler/aws-python-scheduled-cron-project/.venv/lib/python3.10/site-packages/botocore/client.py:960, in BaseClient._make_api_call(self, operation_name, api_params)
#     958     error_code = parsed_response.get("Error", {}).get("Code")
#     959     error_class = self.exceptions.from_code(error_code)
# --> 960     raise error_class(parsed_response, operation_name)
#     961 else:
#     962     return parsed_response
#
# ProvisionedThroughputExceededException: An error occurred (ProvisionedThroughputExceededException) when calling the BatchWriteItem operation (reached max retries: 9): The level of configured provisioned throughput for the table was exceeded. Consider increasing your provisioning level with the UpdateTable API.
